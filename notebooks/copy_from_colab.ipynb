# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# 1. Zip the folder
# !zip -r runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/cascade_run_1788143238/ (stored 0%)
#   adding: content/runs/cascade_run_1788143238/run_config.json (deflated 57%)
#   adding: content/runs/cascade_run_1788143238/cascade_predictions.csv (deflated 65%)
#   adding: content/runs/cascade_run_1788143238/cascade_runtime.csv (deflated 72%)
#   adding: content/runs/cascade_run_1788143238/run_environment.json (deflated 54%)
#   adding: content/runs/cascade_run_1788145507/ (stored 0%)
#   adding: content/runs/cascade_run_1788145507/run_config.json (deflated 57%)
#   adding: content/runs/cascade_run_1788145507/cascade_predictions.csv (deflated 65%)
#   adding: content/runs/cascade_run_1788145507/cascade_runtime.csv (deflated 73%)
#   adding: content/runs/cascade_run_1788145507/run_environment.json (deflated 54%)
#   adding: content/runs/cascade_run_1788142105/ (stored 0%)
#   adding: content/runs/cascade_run_1788142105/run_config.json (deflated 58%)
#   adding: content/runs/cascade_run_1788142105/run_environment.json (deflated 54%)
#   adding: content/runs/cascade_run_1788139385/ (stored 0%)
#   adding: content/runs/cascade_run_1788139385/run_config.json (deflated 58%)
#   adding: content/runs/cascade_run_1788139385/run_environment.json (deflated 54%)
#   adding: content/runs/direct_run_1788151795/ (stored 0%)
#   adding: content/runs/direct_run_1788151795/runtime_per_clip.png (deflated 3%)
#   adding: content/runs/direct_run_1788151795/run_config.json (deflated 55%)
#   adding: content/runs/direct_run_1788151795/direct_predictions.csv (deflated 64%)
#   adding: content/runs/direct_run_1788151795/run_summary.json (deflated 58%)
#   adding: content/runs/direct_run_1788151795/run_environment.json (deflated 51%)
#   adding: content/runs/direct_run_1788151795/runtime_vs_audio_duration.png (deflated 3%)
#   adding: content/runs/direct_run_1788151795/direct_runtime.csv (deflated 66%)
#   adding: content/runs/cascade_run_1788139441/ (stored 0%)
#   adding: content/runs/cascade_run_1788139441/runtime_per_clip.png (deflated 15%)
#   adding: content/runs/cascade_run_1788139441/run_config.json (deflated 57%)
#   adding: content/runs/cascade_run_1788139441/run_summary.json (deflated 60%)
#   adding: content/runs/cascade_run_1788139441/cascade_predictions.csv (deflated 48%)
#   adding: content/runs/cascade_run_1788139441/cascade_runtime.csv (deflated 56%)
#   adding: content/runs/cascade_run_1788139441/run_environment.json (deflated 55%)
#   adding: content/runs/cascade_run_1788139441/runtime_vs_audio_duration.png (deflated 20%)
#   adding: content/runs/cascade_run_1788144872/ (stored 0%)
#   adding: content/runs/cascade_run_1788144872/run_config.json (deflated 57%)
#   adding: content/runs/cascade_run_1788144872/cascade_predictions.csv (deflated 65%)
#   adding: content/runs/cascade_run_1788144872/cascade_runtime.csv (deflated 74%)
#   adding: content/runs/cascade_run_1788144872/run_environment.json (deflated 54%)
#   adding: content/runs/cascade_run_1788143100/ (stored 0%)
#   adding: content/runs/cascade_run_1788143100/run_config.json (deflated 56%)
#   adding: content/runs/cascade_run_1788143100/run_environment.json (deflated 54%)
#   adding: content/runs/cascade_run_1788146589/ (stored 0%)
#   adding: content/runs/cascade_run_1788146589/runtime_per_clip.png (deflated 8%)
#   adding: content/runs/cascade_run_1788146589/run_config.json (deflated 57%)
#   adding: content/runs/cascade_run_1788146589/run_summary.json (deflated 60%)
#   adding: content/runs/cascade_run_1788146589/cascade_predictions.csv (deflated 66%)
#   adding: content/runs/cascade_run_1788146589/cascade_runtime.csv (deflated 65%)
#   adding: content/runs/cascade_run_1788146589/run_environment.json (deflated 55%)
#   adding: content/runs/cascade_run_1788146589/runtime_vs_audio_duration.png (deflated 6%)
#   adding: content/runs/cascade_run_1788146368/ (stored 0%)
#   adding: content/runs/cascade_run_1788146368/run_config.json (deflated 56%)
#   adding: content/runs/cascade_run_1788146368/run_environment.json (deflated 54%)

# %%
# 1. Zip the folder
# !zip -r outputs.zip /content/outputs

# %%
# 1. Zip the folder
# !zip -r results.zip /content/results
