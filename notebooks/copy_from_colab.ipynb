# %%
# 1. Zip the folder
# !zip -r outputs.zip /content/outputs

# 2. Download the zip file
from google.colab import files
files.download('outputs.zip')
# Out:
#   adding: content/outputs/ (stored 0%)
#   adding: content/outputs/timing/ (stored 0%)
#   adding: content/outputs/timing/timing_test_35_clips_results.parquet (deflated 65%)
#   adding: content/outputs/timing/timing_test_35_clips_results.csv (deflated 66%)
#   adding: content/outputs/timing/timing_test_environment.json (deflated 41%)

# %%
# 1. Zip the folder
# !zip -r results.zip /content/results

# 2. Download the zip file
from google.colab import files
files.download('results.zip')
# Out:
#   adding: content/results/ (stored 0%)
#   adding: content/results/figures/ (stored 0%)
#   adding: content/results/figures/cascade_runtime_breakdown.png (deflated 31%)
#   adding: content/results/figures/timing_direct_vs_cascade_35_clips.png (deflated 9%)
#   adding: content/results/figures/timing_vs_audio_duration.png (deflated 19%)
#   adding: content/results/figures/realtime_factor_35_clips.png (deflated 10%)
